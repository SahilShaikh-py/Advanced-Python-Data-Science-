# %% [markdown]
# # Lesson 1: Artificial Neural Networks (ANN), Backpropagation and TensorFlow
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SahilShaikh-py/Advanced-Python-Data-Science-/blob/main/04-deep-learning-neural-networks/01_artificial_neural_networks_tf.ipynb)
#
# ## 1. Definition
# - Artificial Neural Networks process information through interconnected layers of artificial neurons.
# - Backpropagation applies calculus chain rules to compute parameter loss gradients across multi-layer networks.
#
# ## 2. Key Features
# - Forward propagation computes activation values layer-by-layer: z = W*X + b -> a = f(z).
# - Activation functions (ReLU, Sigmoid, Softmax) introduce non-linear decision boundaries.
# - Loss functions (Binary/Categorical Cross-Entropy) measure discrepancy against actual labels.
# - Optimizers (Adam, SGD) update network weight matrices based on computed backpropagation gradients.
#
# ## 3. Real-World Uses
# - High-dimensional tabular classification and pattern recognition.
# - Credit score rating modeling and customer behavior prediction.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

# Live Instructor Code-Along: Multi-Layer Perceptron (ANN) Model
X_train = np.random.rand(500, 10)
y_train = np.random.choice([0, 1], size=500)

model = models.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dropout(0.2),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1)

print("Training Complete. Final Loss:", round(history.history['loss'][-1], 4))

# %% [markdown]
# ## 4. Student Hands-On Lab
# **Exercise 1:** Add an `EarlyStopping` callback to `model.fit()` monitoring `val_loss` with `patience=3`.
